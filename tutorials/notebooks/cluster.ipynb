# %%
import sys
import os

# Get the absolute path of the project root directory
project_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))

# Add the project root directory to the Python path
sys.path.append(project_root)

# %%
import pandas as pd

project_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))

# Define the path to the data directory
data_dir = os.path.join(project_root, 'data')

# Example: Access a specific data file in the data directory
data_file_path = os.path.join(data_dir, 'MAR_per_OAR_for_patients.csv')
df = pd.read_csv(data_file_path)

data = df[['95HD', 'VolDice', 'SurfDist','JaccardIndex', 'APL', 'FNPL', 'FNV', 'OAR', 'patient']]

# %%
from AutoML.analyzer import AutoMLAnalyzer

analyzer = AutoMLAnalyzer(data)

analyzer.run()
# Out:
# Mapping file not found checking for outliers in categorical variables...
#   - No Outliers found in OAR
#   - No Outliers found in patient
# ╒═════════════════════════╤════════════════╤═══════════╤═════════════════╕
# │                         │                │ Missing   │ Overall         │
# ╞═════════════════════════╪════════════════╪═══════════╪═════════════════╡
# │ n                       │                │           │ 380             │
# ├─────────────────────────┼────────────────┼───────────┼─────────────────┤
# │ 95HD, mean (SD)         │                │ 0         │ 6.2 (21.9)      │
# ├─────────────────────────┼────────────────┼───────────┼─────────────────┤
# │ VolDice, mean (SD)      │                │ 0         │ 0.8 (0.1)       │
# ├─────────────────────────┼────────────────┼───────────┼─────────────────┤
# │ SurfDist, mean (SD)     │                │ 0         │ 1.3 (1.9)       │
# ├─────────────────────────┼────────────────┼───────────┼─────────────────┤
# ...

# %%
from AutoML.trainer import AutoMLTrainer

# %%
trainer = AutoMLTrainer(task='cluster', search='random', cv=2, config_path='/home/oem/Documents/CDI/AutoML/configs/config.yaml')

# %%
trainer.fit(data, 'MAR', exclude=['OAR', 'patient',], n_iter=2)
# Out:
# Dataset size: 380
#
# Iterating search through 486 hyperparameters for km.
#
# Iterating search through 225 hyperparameters for ap.
#
# Iterating search through 54 hyperparameters for sc.
# /home/oem/.local/lib/python3.8/site-packages/sklearn/cluster/_affinity_propagation.py:143: ConvergenceWarning: Affinity propagation did not converge, this model may return degenerate cluster centers and labels.
#   warnings.warn(
# /home/oem/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:794: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to 0.0. Details:
# Traceback (most recent call last):
#   File "/home/oem/.local/lib/python3.8/site-packages/sklearn/metrics/_scorer.py", line 115, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
# TypeError: _score() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# ...
